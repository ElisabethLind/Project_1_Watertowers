# %% [markdown]
# ### Watertanks NYC

# %%
# Source: https://data.cityofnewyork.us/Health/Self-Reported-Drinking-Water-Tank-Inspection-Resul/gjm4-k24g/about_data
# https://towardsdatascience.com/exploring-new-york-city-water-tank-inspection-data-855c5776c566

# %%
# Wir importieren pandas 
import pandas as pd
import matplotlib

# %%
# Wir machen ein Dataframe aus dem CSV-File, das wir zuvor runtergladen haben. 
df =pd.read_csv("Self-Reported_Drinking_Water_Tank_Inspection_Results_20240629.csv")
df
# Out:
#              BIN    BOROUGH      ZIP HOUSE_NUM       STREET_NAME  BLOCK   LOT  \
# 0      1032173.0  MANHATTAN  10024.0       156  West 86th Street   1216    54
# 1      2091269.0      BRONX  10454.0       640   east 137 street   2548     1
# 2      1043090.0  MANHATTAN  10021.0       196  East 75th Street   1409    40
# 3      3327711.0   BROOKLYN  11203.0       451   Clarkson Avenue   4829     1
# 4      1035727.0  MANHATTAN  10022.0       520       MADISON AVE   1289    14
# ...          ...        ...      ...       ...               ...    ...   ...
# 50279  1087170.0  MANHATTAN  10007.0       101         WARREN ST    142  7501
# 50280  1053892.0  MANHATTAN  10037.0        10   WEST 135 STREET   1730    45
# 50281  3059901.0   BROOKLYN  11249.0       626       Wythe Place   2175    70
# 50282  1030738.0  MANHATTAN  10023.0       240    West 75 Street   1166   154
# 50283  1030903.0  MANHATTAN  10024.0       390   WEST END AVENUE   1170  7502
#
# ...

# %%
# Wir schauen uns die Spalten an: 

df.keys()
# Out:
# Index(['BIN', 'BOROUGH', 'ZIP', 'HOUSE_NUM', 'STREET_NAME', 'BLOCK', 'LOT',
#        'CONFIRMATION_NUM', 'REPORTING_YEAR', 'TANK_NUM', 'INSPECTION_BY_FIRM',
#        'INSPECTION_PERFORMED', 'INSPECTION_DATE', 'GI_REQ_INTERNAL_STRUCTURE',
#        'GI_RESULT_INTERNAL_STRUCTURE', 'GI_REQ_EXTERNAL_STRUCTURE',
#        'GI_RESULT_EXTERNAL_STRUCTURE', 'GI_REQ_OVERFLOW_PIPES',
#        'GI_RESULT_OVERFLOW_PIPES', 'GI_REQ_ACCESS_LADDERS',
#        'GI_RESULT_ACCESS_LADDERS', 'GI_REQ_AIR_VENTS', 'GI_RESULT_AIR_VENTS',
#        'GI_REQ_ROOF_ACCESS', 'GI_RESULT_ROOF_ACCESS', 'SI_REQ_SEDIMENT',
#        'SI_RESULT_SEDIMENT', 'SI_REQ_BIOLOGICAL_GROWTH',
#        'SI_RESULT_BIOLOGICAL_GROWTH', 'SI_REQ_DEBRIS_INSECTS',
#        'SI_RESULT_DEBRIS_INSECTS', 'SI_REQ_RODENT_BIRD',
#        'SI_RESULT_RODENT_BIRD', 'SAMPLE_COLLECTED', 'LAB_NAME',
#        'NYS_CERTIFIED', 'ANALYTES', 'COLIFORM', 'ECOLI', 'MEET_STANDARDS',
#        'DELETED', 'LATITUDE', 'LONGITUDE', 'COMMUNITY_BOARD',
# ...

# %%
# wir haben 49 Spalten und 50.284 Zeilen 
df.shape
# Out:
# (50284, 49)

# %%
reduced_df = df[['BOROUGH', 'LATITUDE', 'LONGITUDE', 'NTA']]

# Display the first few rows of the reduced dataframe
print(reduced_df.head())
# Out:
#      BOROUGH   LATITUDE  LONGITUDE                                NTA
# 0  MANHATTAN  40.787280 -73.974075                    Upper West Side
# 1      BRONX  40.805087 -73.915530             Mott Haven-Port Morris
# 2  MANHATTAN  40.771811 -73.959478      Upper East Side-Carnegie Hill
# 3   BROOKLYN  40.655760 -73.944602  Prospect Lefferts Gardens-Wingate
# 4  MANHATTAN  40.760107 -73.974768              Midtown-Midtown South

# %%
ny_noduplicates = reduced_df.drop_duplicates(subset=['LATITUDE', 'LONGITUDE'])
ny_noduplicates
# Out:
#          BOROUGH   LATITUDE  LONGITUDE  \
# 0      MANHATTAN  40.787280 -73.974075
# 1          BRONX  40.805087 -73.915530
# 2      MANHATTAN  40.771811 -73.959478
# 3       BROOKLYN  40.655760 -73.944602
# 4      MANHATTAN  40.760107 -73.974768
# ...          ...        ...        ...
# 49798      BRONX  40.821967 -73.816706
# 49969  MANHATTAN  40.761058 -73.984330
# 50075     QUEENS  40.754056 -73.826638
# 50079     QUEENS  40.745980 -73.893442
# 50098  MANHATTAN  40.775764 -73.983727
#
#                                             NTA
# 0                               Upper West Side
# 1                        Mott Haven-Port Morris
# 2                 Upper East Side-Carnegie Hill
# 3             Prospect Lefferts Gardens-Wingate
# 4                         Midtown-Midtown South
# ...                                         ...
# 49798  Schuylerville-Throgs Neck-Edgewater Park
# 49969                     Midtown-Midtown South
# 50075                                  Flushing
# ...

# %%
ny_noduplicates.to_csv("watertowers_new.csv", index = False)

# %%
# ich möchte wissen, wann die ersten Inspektionen aufgenommen wurden: 2000 (aber das sind nur drei) und 2011 (da waren es nur zwei) 
# wirklich begonnen dürfte es 2014 begonnen haben 

df["REPORTING_YEAR"].sort_values(ascending = True).head(20)
# Out:
# 4334     2000
# 49706    2000
# 9518     2000
# 24190    2011
# 22342    2011
# 18801    2014
# 19499    2014
# 47322    2014
# 41319    2014
# 23362    2014
# 41328    2014
# 30400    2014
# 6372     2014
# 27270    2014
# 21254    2014
# 16593    2014
# 50219    2014
# 5739     2014
# 25443    2014
# 15234    2014
# Name: REPORTING_YEAR, dtype: int64

# %%
# wieviele Inspektionen gab es in jedem Jahr? 
df["REPORTING_YEAR"].value_counts().head(20)
# Out:
# REPORTING_YEAR
# 2020    6503
# 2023    6024
# 2022    5974
# 2021    5887
# 2019    5804
# 2018    5541
# 2017    4683
# 2015    4584
# 2016    4545
# 2024     717
# 2014      17
# 2000       3
# 2011       2
# Name: count, dtype: int64

# %%
# die Jahre 2000 und 2011, 2014 gab es nur einzelne Eingaben, 2024 sind es noch sehr wenige, weil noch mitten im Jahre: deshalb nehmen wir die Daten von 2015 bis 2023 
filtered_df = df[df["REPORTING_YEAR"].between(2015, 2023)]

# bleiben 49.545 Inspektionen in den Jahren 2015 - 2023 
filtered_df.shape
# Out:
# (49545, 49)

# %%
# so verteilen sich die Inspektionen auf die Jahre - Höchsstand war 2020 
filtered_df["REPORTING_YEAR"].value_counts().sort_index()
# Out:
# REPORTING_YEAR
# 2015    4584
# 2016    4545
# 2017    4683
# 2018    5541
# 2019    5804
# 2020    6503
# 2021    5887
# 2022    5974
# 2023    6024
# Name: count, dtype: int64

# %%
# Grafiksch dargestellt schaut das so aus 
filtered_df["REPORTING_YEAR"].plot(kind="hist", bins=20, title="Inspections on Watertanks per year")
# Out:
# <Axes: title={'center': 'Inspections on Watertanks per year'}, ylabel='Frequency'>

# %%
# ich hätte gerne nur die inspections aus 2023 
# dazu schau ich mir zuerst an, was fpür ein Typ "REPORTING_YEAR" ist - int!!!
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 49545 entries, 0 to 50283
# Data columns (total 49 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   BIN                           49437 non-null  float64
#  1   BOROUGH                       49545 non-null  object
#  2   ZIP                           49475 non-null  float64
#  3   HOUSE_NUM                     49545 non-null  object
#  4   STREET_NAME                   49545 non-null  object
#  5   BLOCK                         49545 non-null  int64
#  6   LOT                           49545 non-null  int64
#  7   CONFIRMATION_NUM              49545 non-null  object
#  8   REPORTING_YEAR                49545 non-null  int64
#  9   TANK_NUM                      49545 non-null  int64
#  10  INSPECTION_BY_FIRM            49523 non-null  object
#  11  INSPECTION_PERFORMED          49545 non-null  object
# ...

# %%
#neue Variable insp2023 - 2023 ohne Anführungszeichen weil ja integer!
insp2023 = df[df["REPORTING_YEAR"] == 2023]
insp2023
# Out:
#              BIN    BOROUGH      ZIP HOUSE_NUM          STREET_NAME  BLOCK  \
# 0      1032173.0  MANHATTAN  10024.0       156     West 86th Street   1216
# 13     1072007.0  MANHATTAN  10065.0       667       MADISON AVENUE   1375
# 30     1001241.0  MANHATTAN  10007.0       225             BROADWAY     88
# 31     1002154.0  MANHATTAN  10013.0         6        Varick Street    189
# 33     1040144.0  MANHATTAN  10022.0       414       EAST 52 STREET   1363
# ...          ...        ...      ...       ...                  ...    ...
# 50255  1035381.0  MANHATTAN  10017.0        89       E. 42nd Street   1280
# 50257  1019519.0  MANHATTAN  10003.0       230     East 15th Street    896
# 50261  1081661.0  MANHATTAN  10003.0        10  Nathan D Perlman Pl    922
# 50276  1082129.0  MANHATTAN  10010.0       234       EAST 22 STREET    902
# 50280  1053892.0  MANHATTAN  10037.0        10      WEST 135 STREET   1730
#
# ...

# %%
ny_noduplicates2023 = insp2023.drop_duplicates(subset=['LATITUDE', 'LONGITUDE'])
ny_noduplicates2023
# Out:
#              BIN    BOROUGH      ZIP HOUSE_NUM        STREET_NAME  BLOCK  \
# 0      1032173.0  MANHATTAN  10024.0       156   West 86th Street   1216
# 13     1072007.0  MANHATTAN  10065.0       667     MADISON AVENUE   1375
# 30     1001241.0  MANHATTAN  10007.0       225           BROADWAY     88
# 31     1002154.0  MANHATTAN  10013.0         6      Varick Street    189
# 33     1040144.0  MANHATTAN  10022.0       414     EAST 52 STREET   1363
# ...          ...        ...      ...       ...                ...    ...
# 50222  1057029.0  MANHATTAN  10025.0       511  West 113th Street   1885
# 50225  1006580.0  MANHATTAN  10003.0       200    East 5th Street    460
# 50257  1019519.0  MANHATTAN  10003.0       230   East 15th Street    896
# 50276  1082129.0  MANHATTAN  10010.0       234     EAST 22 STREET    902
# 50280  1053892.0  MANHATTAN  10037.0        10    WEST 135 STREET   1730
#
#         LOT CONFIRMATION_NUM  REPORTING_YEAR  TANK_NUM  ... MEET_STANDARDS  \
# ...

# %%
reduced_df_2023 = ny_noduplicates2023[['BOROUGH', 'LATITUDE', 'LONGITUDE', 'NTA']]

# %%
astoria = reduced_df_2023[reduced_df["NTA"]== "Astoria"]
astoria
# Out:
# C:\Users\linde\AppData\Local\Temp\ipykernel_16172\3942958133.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   astoria = reduced_df_2023[reduced_df["NTA"]== "Astoria"]
#       BOROUGH   LATITUDE  LONGITUDE      NTA
# 30614  QUEENS  40.763105 -73.930997  Astoria
# 45275  QUEENS  40.763488 -73.933361  Astoria

# %%
reduced_df_2023.to_csv("watertowers_2023.csv", index = False)

# %%
inspections_2019_to_2023 = df[(df["REPORTING_YEAR"] >= 2019) & (df["REPORTING_YEAR"] <= 2023)]

# Display the filtered inspections
print(inspections_2019_to_2023)
# Out:
#              BIN    BOROUGH      ZIP HOUSE_NUM        STREET_NAME  BLOCK  \
# 0      1032173.0  MANHATTAN  10024.0       156   West 86th Street   1216
# 5      1036145.0  MANHATTAN  10017.0       360   LEXINGTON AVENUE   1295
# 6      1080440.0  MANHATTAN  10019.0        17   West 54th Street   1270
# 8      1019948.0  MANHATTAN  10016.0       207   East 30th Street    911
# 9      4436179.0     QUEENS  11691.0       120  Beach 19th Street  15638
# ...          ...        ...      ...       ...                ...    ...
# 50278  1057080.0  MANHATTAN  10025.0       260    Riverside Drive   1888
# 50279  1087170.0  MANHATTAN  10007.0       101          WARREN ST    142
# 50280  1053892.0  MANHATTAN  10037.0        10    WEST 135 STREET   1730
# 50281  3059901.0   BROOKLYN  11249.0       626        Wythe Place   2175
# 50282  1030738.0  MANHATTAN  10023.0       240     West 75 Street   1166
#
#         LOT CONFIRMATION_NUM  REPORTING_YEAR  TANK_NUM  ... MEET_STANDARDS  \
# ...

# %%
ny_noduplicates2019_2023 = inspections_2019_to_2023.drop_duplicates(subset=['LATITUDE', 'LONGITUDE'])
ny_noduplicates2019_2023
# Out:
#              BIN    BOROUGH      ZIP HOUSE_NUM        STREET_NAME  BLOCK  \
# 0      1032173.0  MANHATTAN  10024.0       156   West 86th Street   1216
# 5      1036145.0  MANHATTAN  10017.0       360   LEXINGTON AVENUE   1295
# 6      1080440.0  MANHATTAN  10019.0        17   West 54th Street   1270
# 8      1019948.0  MANHATTAN  10016.0       207   East 30th Street    911
# 9      4436179.0     QUEENS  11691.0       120  Beach 19th Street  15638
# ...          ...        ...      ...       ...                ...    ...
# 49233  1089508.0  MANHATTAN  10021.0       175   EAST 75TH STREET   1410
# 49402  1022051.0  MANHATTAN  10016.0       310   East 40th Street    945
# 49755  1034022.0  MANHATTAN  10024.0       304   WEST   89 STREET   1250
# 50079  4030405.0     QUEENS  11377.0     40-35          72 Street   1304
# 50098  1030346.0  MANHATTAN  10023.0       170   Amsterdam Avenue   1158
#
#         LOT CONFIRMATION_NUM  REPORTING_YEAR  TANK_NUM  ... MEET_STANDARDS  \
# ...

# %%
insp2023["INSPECTION_BY_FIRM"].value_counts()
# Out:
# INSPECTION_BY_FIRM
# Rosenwach Tank Co. LLC              2537
# ISSEKS BROS INC                      959
# American Pipe and Tank               941
# ISSEKS BROS., INC.                   319
# Atlantank, LLC                       157
#                                     ...
# America Pipe and Tank                  1
# Skinner Plumbing & Heating Corp.       1
# American Pipe ad Tank                  1
# American pipe and tank                 1
# Alklem Plumblng Inc                    1
# Name: count, Length: 62, dtype: int64

# %%
filtered_df["INSPECTION_BY_FIRM"].value_counts()
# Out:
# INSPECTION_BY_FIRM
# Rosenwach Tank Co. LLC     21899
# ISSEKS BROS INC             8121
# American Pipe and Tank      3876
# Isseks Bros. Inc.           1759
# isseks bros., inc.          1237
#                            ...
# American Pipe and Tanjk        1
# isseks Bros Inc.               1
# TOTAL SERVICE                  1
# Entity                         1
# American  Pipe & Tank          1
# Name: count, Length: 695, dtype: int64

# %%
# Create a mapping of variations to standardized names
firm_mapping = firm_mapping = {
    "Rosenwach Tank Co. LLC": "Rosenwach Tank Co. LLC",
    "Rosenwach Tank Co LLC": "Rosenwach Tank Co. LLC",
    "Resenwach Tank Company ": "Rosenwach Tank Co. LLC",
    "Rosenawch Tank Co. LLC": "Rosenwach Tank Co. LLC",
    "Resenwach Tank Company": "Rosenwach Tank Co. LLC",
    "ISSEKS BROS INC": "ISSEKS BROS INC",
    "Isseks Bros. Inc.": "ISSEKS BROS INC",
    "isseks bros., inc.": "ISSEKS BROS INC",
    "isseks Bros Inc.": "ISSEKS BROS INC",
    "ISSEKS BROS., INC.": "ISSEKS BROS INC",
    "Isseks Bros Inc": "ISSEKS BROS INC",
    "Isseks Bors. Inc.": "ISSEKS BROS INC",
    "ISSIKS BROS. INC.": "ISSEKS BROS INC",
    "ADRIATIC PLUMBING AND HEATING CORP": "ADRIATIC PLUMBING AND HEATING CORP", 
    "ADRIATIC PLUMBING AND HEATING CORP.": "ADRIATIC PLUMBING AND HEATING CORP", 
    "American Pipe and Tanjk": "American Pipe and Tank",
    "American  Pipe & Tank": "American Pipe and Tank",
    "American Pipe &Tank": "American Pipe and Tank",
    "AMERICAN PIPE  TANK": "American Pipe and Tank",
    "American Pipe & Tank": "American Pipe and Tank",
    "AMERICAN PIPE & TANK": "American Pipe and Tank",
    "American Pipe & Tank Lining Co., Inc": "American Pipe and Tank",       
    "American Pipe and tank": "American Pipe and Tank",
    "American pipe & Tank": "American Pipe and Tank",
    "american pipe and tank inc.": "American Pipe and Tank",
    "AMERICAN PIPE & TANK LINING CO., INC": "American Pipe and Tank",
    "AMERICAN PIPE AND TANK": "American Pipe and Tank",  
    "American Pipe & Tank LINING CO., INC": "American Pipe and Tank",
    "America Pipe & Tank": "American Pipe and Tank",
    "American Pipe and Tank Lining Company": "American Pipe and Tank",
    "american pipe & tank": "American Pipe and Tank",
    "Americn Pipe and Tank": "American Pipe and Tank",
    "american piep and tank inc": "American Pipe and Tank",
    "american pipee and tank inc.": "American Pipe and Tank",
    "American Pipe an Tank": "American Pipe and Tank",
    "american piep and tank inc.": "American Pipe and Tank",
    "american pipe& tank": "American Pipe and Tank",
    "Americanpipe and tank": "American Pipe and Tank",
    "AMERICAN PIPE 7 TANK": "American Pipe and Tank",
    "AMERICAN PUIPE & TANK": "American Pipe and Tank",
    "AmericanPipe and Tank": "American Pipe and Tank",
    "American Pipe and Tank .com": "American Pipe and Tank",
    "American Pipe & Tank Inc., Co.": "American Pipe and Tank",
    "American Piep & Tank Lining Co., Inc": "American Pipe and Tank",
    "American Pipe & Testing": "American Pipe and Tank",
    "AMERICAN Pipe & Tank": "American Pipe and Tank",
    "AMERICA PIPE & TANK COMPANY": "American Pipe and Tank",
    "American PIpe & Tank": "American Pipe and Tank",
    "AMERICAN P[IPE & TANK": "American Pipe and Tank",
    "American Pip and Tank": "American Pipe and Tank",
    "American Pipe & Tank Lining, Inc": "American Pipe and Tank",
    "american pie and tank inc.": "American Pipe and Tank",
    "AMERICAN PIP AND TANK": "American Pipe and Tank",
    "American Pip & tank": "American Pipe and Tank",
    "AMERICAN PIPE & TANK LINING COMPANY": "American Pipe and Tank",
    "Americna Pipe and Tank": "American Pipe and Tank",
    "AmericnaPipe and Tank ": "American Pipe and Tank",
    "Americ": "American Pipe and Tank", 
    "Amer": "American Pipe and Tank",
    "Amercian Pipe and Tank": "American Pipe and Tank",
    "Americn Pipe & Tank ": "American Pipe and Tank",
    "Anerican Pipe and Tank": "American Pipe and Tank",
    "AmericnaPipe and Tank": "American Pipe and Tank",
    "Anerican Pipe and Tan": "American Pipe and Tank",
    "Americn Pipe & Tank ": "American Pipe and Tank",
    "Atlantank, LLC": "Atlantank, LLC",
    "Atlantank": "Atlantank, LLC",
    "Atlantank, LLC.": "Atlantank, LLC",
    "Atlantank,LLC ": "Atlantank, LLC",
    "ATLANKTANK LLC": "Atlantank, LLC",
    "Atlantank,LLC": "Atlantank, LLC",
    "Alantank ": "Atlantank, LLC",
    "tlantank, LLC": "Atlantank, LLC",
    "Environmental Building Solutions, LLC": "Environmental Building Solutions, LLC",
    "Environmental Building Solutions": "Environmental Building Solutions, LLC",
    "Environmental builbing solution,LLC":"Environmental Building Solutions, LLC",
    "Envirnmental Buildings Solutions": "Environmental Building Solutions, LLC",
    "Environmental Business Solutions": "Environmental Building Solutions, LLC",
    "envionmental builing solution llc": "Environmental Building Solutions, LLC",
    "Environmental Building Solution": "Environmental Building Solutions, LLC",
    "Environmental Building Services": "Environmental Building Solutions, LLC",
    "environmentalbuildingsolutions": "Environmental Building Solutions, LLC",
    "Environmental Engineering Solutions. P.C.": "Environmental Building Solutions, LLC",
    "international wood tanks": "International Wood Tanks",
    "International Wood Tanks": "International Wood Tanks",
    "International Wood Tank": "International Wood Tanks",
    "International Wood tanks": "International Wood Tanks",
    "International Wood tank": "International Wood Tanks",
    "Nalco": "Nalco",
    "Nalco Company": "Nalco",
    "Nalco Water": "Nalco",
    "NALCO": "Nalco",
    "NEW YORK PLUMBING HEATING COOLING CORP": "NEW YORK PLUMBING HEATING COOLING CORP ",
    "new york plumbing": "NEW YORK PLUMBING HEATING COOLING CORP ",
    "New York Plumbing Heating Cooling": "NEW YORK PLUMBING HEATING COOLING CORP",
    "New York Plumbing Heating Cooling Corp": "NEW YORK PLUMBING HEATING COOLING CORP",
    "new york plubming": "NEW YORK PLUMBING HEATING COOLING CORP",
    "NEW YORK PLUMBING HEATING COOLING CORP.": "NEW YORK PLUMBING HEATING COOLING CORP",
    "new york plumbing heating cooling corp": "NEW YORK PLUMBING HEATING COOLING CORP",
    "NEW YORK PLUMBING HEATING COOLING CORP": "NEW YORK PLUMBING HEATING COOLING CORP",
    "NEW YORK PLUMBING HEATING COOLING": "NEW YORK PLUMBING HEATING COOLING CORP",
    "New York Plumbing Heating": "NEW YORK PLUMBING HEATING COOLING CORP",
    "New York Plumbing HEating Cooling": "NEW YORK PLUMBING HEATING COOLING CORP",
    "NY Plumbing and heating": "NEW YORK PLUMBING HEATING COOLING CORP",
    "New York Plumbing": "NEW YORK PLUMBING HEATING COOLING CORP",
    "ny plumbing": "NEW YORK PLUMBING HEATING COOLING CORP",
    "NY Plumbing and heating": "NEW YORK PLUMBING HEATING COOLING CORP",
    "chriso@nyplumbing.com": "NEW YORK PLUMBING HEATING COOLING CORP",
    "The Metro Group Inc": "The Metro Group, Inc.",
    "Metro Group ": "The Metro Group, Inc.",
    "chemical specifics inc": "Chemical Specifics Inc",
    "TOTAL SERVICE": "Total Service",
    "Entity": "Entity"
}

# Replace variations with standardized names
filtered_df.loc[:,"INSPECTION_BY_FIRM"] = filtered_df["INSPECTION_BY_FIRM"].replace(firm_mapping)

# %%
# Count the values after replacement
firm_counts = filtered_df["INSPECTION_BY_FIRM"].value_counts()

# %%
# Standardize firm names containing "issek" to "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("issek", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("isseks", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("issecs", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("issec", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("issue", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Iseek", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Iseeks", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Iseec", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Iseecs", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("ISSKES", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Isecks", case=False, na=False), "INSPECTION_BY_FIRM"] = "ISSEKS BROS INC"

# %%
# Standardize firm names containing "issek" to "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Pro", case=False, na=False), "INSPECTION_BY_FIRM"] = "Pro-Tech Plumbing & Heating Corp."
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Pro-Tech", case=False, na=False), "INSPECTION_BY_FIRM"] = "Pro-Tech Plumbing & Heating Corp."

# %%
# Standardize firm names containing "issek" to "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("AMERICAN", case=False, na=False), "INSPECTION_BY_FIRM"] = "American Pipe and Tank"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("American", case=False, na=False), "INSPECTION_BY_FIRM"] = "American Pipe and Tank"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("AMERICA", case=False, na=False), "INSPECTION_BY_FIRM"] = "American Pipe and Tank"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("America", case=False, na=False), "INSPECTION_BY_FIRM"] = "American Pipe and Tank"

# %%
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("nalco", case=False, na=False), "INSPECTION_BY_FIRM"] = "Nalco"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("NALCO", case=False, na=False), "INSPECTION_BY_FIRM"] = "Nalco"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Nalco", case=False, na=False), "INSPECTION_BY_FIRM"] = "Nalco"

# %%
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("NOBLE", case=False, na=False), "INSPECTION_BY_FIRM"] = "NOBLE MECHANICAL"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("noble", case=False, na=False), "INSPECTION_BY_FIRM"] = "NOBLE MECHANICAL"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Noble", case=False, na=False), "INSPECTION_BY_FIRM"] = "NOBLE MECHANICAL"

# %%
# Standardize firm names containing "issek" to "ISSEKS BROS INC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Building Solutions", case=False, na=False), "INSPECTION_BY_FIRM"] = "Environmental Building Solutions, LLC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Bldg Solutions", case=False, na=False), "INSPECTION_BY_FIRM"] = "Environmental Building Solutions, LLC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Environmental Engineering Solutions P.C.", case=False, na=False), "INSPECTION_BY_FIRM"] = "Environmental Engineering Solutions. P.C."

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Atlantic", case=False, na=False), "INSPECTION_BY_FIRM"] = "Atlantic Tank"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("AtlanticTank", case=False, na=False), "INSPECTION_BY_FIRM"] = "Atlantic Tank"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Altantic", case=False, na=False), "INSPECTION_BY_FIRM"] = "Atlantic Tank"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Airtek", case=False, na=False), "INSPECTION_BY_FIRM"] = "Airtek Environmental Corp"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("rosenwach", case=False, na=False), "INSPECTION_BY_FIRM"] = "Rosenwach Tank Co. LLC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Rosnewach", case=False, na=False), "INSPECTION_BY_FIRM"] = "Rosenwach Tank Co. LLC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Rosenwcah", case=False, na=False), "INSPECTION_BY_FIRM"] = "Rosenwach Tank Co. LLC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Rosewach", case=False, na=False), "INSPECTION_BY_FIRM"] = "Rosenwach Tank Co. LLC"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Atlantank", case=False, na=False), "INSPECTION_BY_FIRM"] = "Atlantank, LLC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Atlantan", case=False, na=False), "INSPECTION_BY_FIRM"] = "Atlantank, LLC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Atlantatank", case=False, na=False), "INSPECTION_BY_FIRM"] = "Atlantank, LLC"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Alantank", case=False, na=False), "INSPECTION_BY_FIRM"] = "Atlantank, LLC"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Metro", case=False, na=False), "INSPECTION_BY_FIRM"] = "The Metro Group, Inc."
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("AQUAGY", case=False, na=False), "INSPECTION_BY_FIRM"] = "Aquagy Watersolv. Inc. "
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Aquagy", case=False, na=False), "INSPECTION_BY_FIRM"] = "Aquagy Watersolv. Inc. "
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("aquagy", case=False, na=False), "INSPECTION_BY_FIRM"] = "Aquagy Watersolv. Inc. "

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Aqua", case=False, na=False), "INSPECTION_BY_FIRM"] = "Aqua Treat Ltd"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Acqua", case=False, na=False), "INSPECTION_BY_FIRM"] = "Aqua Treat Ltd"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("North Shore", case=False, na=False), "INSPECTION_BY_FIRM"] = "North Shore Towers"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Ambient", case=False, na=False), "INSPECTION_BY_FIRM"] = "Ambient Group Inc "
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("ambient", case=False, na=False), "INSPECTION_BY_FIRM"] = "Ambient Group Inc "
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("AMBIENT", case=False, na=False), "INSPECTION_BY_FIRM"] = "Ambient Group Inc "

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Adriatic", case=False, na=False), "INSPECTION_BY_FIRM"] = "ADRIATIC PLUMBING AND HEATING CORP"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Culligan", case=False, na=False), "INSPECTION_BY_FIRM"] = "Culligan of Manhattan"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Culigan", case=False, na=False), "INSPECTION_BY_FIRM"] = "Culligan of Manhattan"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Cullligan", case=False, na=False), "INSPECTION_BY_FIRM"] = "Culligan of Manhattan"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Culligna", case=False, na=False), "INSPECTION_BY_FIRM"] = "Culligan of Manhattan"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Tower Water", case=False, na=False), "INSPECTION_BY_FIRM"] = "Tower Water Management"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Tower Warter", case=False, na=False), "INSPECTION_BY_FIRM"] = "Tower Water Management"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Sean Coakley", case=False, na=False), "INSPECTION_BY_FIRM"] = "Sean Coakley Plumbing & Heating"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("seancoakleyplumbing@gmail.com", case=False, na=False), "INSPECTION_BY_FIRM"] = "Sean Coakley Plumbing & Heating"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Cascade", case=False, na=False), "INSPECTION_BY_FIRM"] = "Cascade Water Services"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Casade", case=False, na=False), "INSPECTION_BY_FIRM"] = "Cascade Water Services"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Cacade", case=False, na=False), "INSPECTION_BY_FIRM"] = "Cascade Water Services"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("KLEM", case=False, na=False), "INSPECTION_BY_FIRM"] = "Alklem Plumbing Inc"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Alklem", case=False, na=False), "INSPECTION_BY_FIRM"] = "Alklem Plumbing Inc"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Ford", case=False, na=False), "INSPECTION_BY_FIRM"] = "Ford Tank Maintenance CO"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Chemical", case=False, na=False), "INSPECTION_BY_FIRM"] = "Chemical Specifics Inc."

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Wood", case=False, na=False), "INSPECTION_BY_FIRM"] = "International Wood Tanks"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("wood", case=False, na=False), "INSPECTION_BY_FIRM"] = "International Wood Tanks"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Grosser", case=False, na=False), "INSPECTION_BY_FIRM"] = "P.W. Grosser Consulting"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("All Day", case=False, na=False), "INSPECTION_BY_FIRM"] = "All Day Plumbing&Heating"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Barclay", case=False, na=False), "INSPECTION_BY_FIRM"] = "Barclay Water Management"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("VIP", case=False, na=False), "INSPECTION_BY_FIRM"] = "VIP sprinkler"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Vip", case=False, na=False), "INSPECTION_BY_FIRM"] = "VIP sprinkler"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("vip", case=False, na=False), "INSPECTION_BY_FIRM"] = "VIP sprinkler"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("JMK", case=False, na=False), "INSPECTION_BY_FIRM"] = "JMK Maintenance"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("MJN", case=False, na=False), "INSPECTION_BY_FIRM"] = "MJM Plumbing"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("mjm", case=False, na=False), "INSPECTION_BY_FIRM"] = "MJM Plumbing"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("MJM", case=False, na=False), "INSPECTION_BY_FIRM"] = "MJM Plumbing"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("EBS", case=False, na=False), "INSPECTION_BY_FIRM"] = "EBS Consulting Group"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("JMZ", case=False, na=False), "INSPECTION_BY_FIRM"] = "JMZ Maintenance"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("MMO", case=False, na=False), "INSPECTION_BY_FIRM"] = "JMZ Maintenance"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("DCAS", case=False, na=False), "INSPECTION_BY_FIRM"] = "DCAS"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("TVS", case=False, na=False), "INSPECTION_BY_FIRM"] = "TVS Mechanical Corp."
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("UNHQ", case=False, na=False), "INSPECTION_BY_FIRM"] = "U.N.H.Q"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("U.N.H.Q", case=False, na=False), "INSPECTION_BY_FIRM"] = "U.N.H.Q"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("ADK", case=False, na=False), "INSPECTION_BY_FIRM"] = "ADK Water Solutions"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("EMSL", case=False, na=False), "INSPECTION_BY_FIRM"] = "EMSL Analytical, Inc"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Smith", case=False, na=False), "INSPECTION_BY_FIRM"] = "Fred Smith Plumbing"

filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Golds", case=False, na=False), "INSPECTION_BY_FIRM"] = "Golds Plumbing Corp."
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Gold", case=False, na=False), "INSPECTION_BY_FIRM"] = "Golds Plumbing Corp."

filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Delta", case=False, na=False), "INSPECTION_BY_FIRM"] = "Delta Tank Welding"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Roof Tank", case=False, na=False), "INSPECTION_BY_FIRM"] = "Roof Tank Company"

# %%
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Enviromental Hygieni Services", case=False, na=False), "INSPECTION_BY_FIRM"] = "Environmental Hygiene Services"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Environmental Services Inc", case=False, na=False), "INSPECTION_BY_FIRM"] = "Environmental Hygiene Services"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Pure", case=False, na=False), "INSPECTION_BY_FIRM"] = "Pure Water Solutions"

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("Skinner", case=False, na=False), "INSPECTION_BY_FIRM"] = "Skinner Plumbing & Heating Corp."

# %%
# Standardize firm names 
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("M&S", case=False, na=False), "INSPECTION_BY_FIRM"] = "M&S Building Services Inc"
filtered_df.loc[filtered_df["INSPECTION_BY_FIRM"].str.contains("m&s", case=False, na=False), "INSPECTION_BY_FIRM"] = "M&S Building Services Inc"

# %%
insp2023_clean = filtered_df[filtered_df["REPORTING_YEAR"] == 2023]
insp2023_clean["INSPECTION_BY_FIRM"].value_counts()
# Out:
# INSPECTION_BY_FIRM
# Rosenwach Tank Co. LLC                     2544
# ISSEKS BROS INC                            1852
# American Pipe and Tank                      955
# Nalco                                       224
# Atlantank, LLC                              164
# The Metro Group, Inc.                       108
# Culligan of Manhattan                        50
# DCAS                                         35
# International Wood Tanks                     17
# ADRIATIC PLUMBING AND HEATING CORP           11
# Alklem Plumbing Inc                           9
# NEW YORK PLUMBING HEATING COOLING CORP        8
# North Shore Towers                            8
# Sean Coakley Plumbing & Heating               8
# P.W. Grosser Consulting                       8
# JB&B Environmental                            5
# All Day Plumbing&Heating                      5
# H2M architects + engineers                    4
# NOBLE MECHANICAL                              2
# ...

# %%
# Count the values after replacement
firm_counts = filtered_df["INSPECTION_BY_FIRM"].value_counts()


pd.set_option('display.max_rows', None)
print(firm_counts)
# Out:
# INSPECTION_BY_FIRM
# Rosenwach Tank Co. LLC                       22026
# ISSEKS BROS INC                              15756
# American Pipe and Tank                        5872
# Nalco                                         1369
# Atlantank, LLC                                1241
# Culligan of Manhattan                          645
# JMZ Maintenance                                404
# The Metro Group, Inc.                          399
# DCAS                                           303
# International Wood Tanks                       153
# Alklem Plumbing Inc                            129
# ADRIATIC PLUMBING AND HEATING CORP             128
# Environmental Building Solutions, LLC           99
# NEW YORK PLUMBING HEATING COOLING CORP          88
# Cascade Water Services                          82
# Sean Coakley Plumbing & Heating                 70
# Atlantic Tank                                   52
# North Shore Towers                              48
# ...

# %%
# Wie viele Zeilen haben wir jetzt?
firm_counts.shape
# Out:
# (145,)

# %%
# Summe aller Inspektionen
firm_counts.sum()
# Out:
# 49523

# %%
# Wieviele entfallen auf die Topten 
firm_counts.head(10).sum()
# Out:
# 48168

# %%
#alle Firmen mit weniger als 10 Nennungen fallen in die Kategorie "Rest"
other = firm_counts[firm_counts < 100].index.tolist()

# Step 3: Replace firms with 5 counts or fewer with 'rest'
filtered_df["INSPECTION_BY_FIRM"] = filtered_df["INSPECTION_BY_FIRM"].apply(lambda x: "other" if x in other else x)

# Count the values after replacement
updated_firm_counts = filtered_df["INSPECTION_BY_FIRM"].value_counts()

# Display the updated counts
print(updated_firm_counts)
# Out:
# INSPECTION_BY_FIRM
# Rosenwach Tank Co. LLC                22026
# ISSEKS BROS INC                       15756
# American Pipe and Tank                 5872
# Nalco                                  1369
# Atlantank, LLC                         1241
# other                                  1098
# Culligan of Manhattan                   645
# JMZ Maintenance                         404
# The Metro Group, Inc.                   399
# DCAS                                    303
# International Wood Tanks                153
# Alklem Plumbing Inc                     129
# ADRIATIC PLUMBING AND HEATING CORP      128
# Name: count, dtype: int64
# C:\Users\linde\AppData\Local\Temp\ipykernel_19464\2099632936.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
updated_firm_counts.plot(kind="barh")
# Out:
# <Axes: ylabel='INSPECTION_BY_FIRM'>

# %%
pluto_df = pd.read_csv("pluto_24v2.csv")
pluto_df
# Out:
# C:\Users\linde\AppData\Local\Temp\ipykernel_19648\2687954612.py:1: DtypeWarning: Columns (21,22,24,25,26,28,65,66,88) have mixed types. Specify dtype option on import or set low_memory=False.
#   pluto_df = pd.read_csv("pluto_24v2.csv")
#        borough  block  lot     cd    bct2020     bctcb2020  ct2010  cb2010  \
# 0           SI    490   45  501.0  5002100.0  5.002100e+10    21.0  2019.0
# 1           SI   2965   12  501.0  5003600.0  5.003600e+10    36.0  1000.0
# 2           SI   2965  110  501.0  5003600.0  5.003600e+10    36.0  1000.0
# 3           SI   2965   11  501.0  5003600.0  5.003600e+10    36.0  1000.0
# 4           SI   2965   20  501.0  5003600.0  5.003600e+10    36.0  1000.0
# ...        ...    ...  ...    ...        ...           ...     ...     ...
# 859007      SI   2973   11  501.0  5003600.0  5.003600e+10    36.0  2001.0
# 859008      SI   3417  169  502.0  5007002.0  5.007002e+10    70.0  4012.0
# ...

# %%
pluto_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 859012 entries, 0 to 859011
# Data columns (total 92 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   borough               859012 non-null  object
#  1   block                 859012 non-null  int64
#  2   lot                   859012 non-null  int64
#  3   cd                    857488 non-null  float64
#  4   bct2020               857443 non-null  float64
#  5   bctcb2020             857443 non-null  float64
#  6   ct2010                857443 non-null  float64
#  7   cb2010                857443 non-null  float64
#  8   schooldist            856759 non-null  float64
#  9   council               857486 non-null  float64
#  10  zipcode               856747 non-null  float64
#  11  firecomp              856740 non-null  object
#  12  policeprct            856754 non-null  float64
#  13  healthcenterdistrict  856754 non-null  float64
# ...

# %%
pluto_reduced_df = pluto_df[['borough', 'latitude', 'longitude', 'numfloors']]
pluto_reduced_df
# Out:
#        borough   latitude  longitude  numfloors
# 0           SI  40.628871 -74.075060        1.0
# 1           SI  40.615436 -74.074678        2.0
# 2           SI  40.615510 -74.074487        2.0
# 3           SI  40.615474 -74.074566        2.0
# 4           SI  40.615273 -74.075031        2.0
# ...        ...        ...        ...        ...
# 859007      SI  40.612335 -74.072647        1.0
# 859008      SI  40.590156 -74.074790        NaN
# 859009      SI  40.598490 -74.063762        NaN
# 859010      SI  40.595247 -74.084032        NaN
# 859011      SI  40.605724 -74.083840        NaN
#
# [859012 rows x 4 columns]

# %%
pluto_reduced_df["numfloors"].sort_values(ascending = False)
# Out:
# 125240    342.87
# 51184     104.00
# 728632    102.00
# 651979     98.00
# 276661     90.00
#            ...
# 859006       NaN
# 859008       NaN
# 859009       NaN
# 859010       NaN
# 859011       NaN
# Name: numfloors, Length: 859012, dtype: float64

# %%
pluto_higherthan6floors_df= pluto_reduced_df[pluto_reduced_df["numfloors"] > 6.00]
pluto_higherthan6floors_df
# Out:
#        borough   latitude  longitude  numfloors
# 543         BK  40.595771 -73.997670        9.0
# 546         BK  40.596200 -73.998135       31.0
# 2160        MN  40.724268 -74.009658        7.0
# 2165        MN  40.716596 -74.007287        7.0
# 2166        MN  40.717000 -74.008816        8.0
# ...        ...        ...        ...        ...
# 858570      BX  40.816988 -73.928521       26.0
# 858872      MN  40.744881 -73.992190        7.0
# 858949      MN  40.710034 -74.005699       12.0
# 858972      MN  40.752361 -73.991226       17.0
# 858998      MN  40.712618 -74.016586       27.0
#
# [12074 rows x 4 columns]

# %%
clean_df = pluto_higherthan6floors_df.drop_duplicates(subset=['latitude', 'longitude'])
clean_df
# Out:
#        borough   latitude  longitude  numfloors
# 543         BK  40.595771 -73.997670        9.0
# 546         BK  40.596200 -73.998135       31.0
# 2160        MN  40.724268 -74.009658        7.0
# 2165        MN  40.716596 -74.007287        7.0
# 2166        MN  40.717000 -74.008816        8.0
# ...        ...        ...        ...        ...
# 858302      BK  40.677261 -73.920494       14.0
# 858570      BX  40.816988 -73.928521       26.0
# 858872      MN  40.744881 -73.992190        7.0
# 858972      MN  40.752361 -73.991226       17.0
# 858998      MN  40.712618 -74.016586       27.0
#
# [11926 rows x 4 columns]

# %%
clean_df.to_csv("buildings.csv")
